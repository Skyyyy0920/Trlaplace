# %%
import tensorflow as tf
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
loss_1 = 3.07
r_1 = 89.40
bs_1 = 0.973

loss_2 = [34.67, 21.62, 10.61, 5.98, 4.74, 3.14] # 3.13, 2.97
r_2 = [15.97, 48.89, 76.48, 84.97, 86.63, 89.13] # 89.27, 89.80
bs_2 = [0.874, 0.895, 0.943, 0.964, 0.969, 0.975] # 0.975, 0.975

loss_3 = [36.00, 34.64, 14.86, 7.38, 5.02, 3.30] # 3.66, 3.17
r_3 = [12.60, 14.68, 66.62, 82.08, 86.43, 89.04] # 88.15, 89.23
bs_3 = [0.855, 0.874, 0.927, 0.952, 0.964, 0.969] # 0.969, 0.968

loss_4 = [2.98, 2.99, 3.02, 2.94, 2.93, 3.03] # 3.00,2.98
r_4 = [89.45, 89.47, 89.34, 89.54, 89.68, 89.40] # 89.37, 89.60
bs_4 =[0.971, 0.973, 0.971, 0.972, 0.975, 0.971] # 0.976, 0.976


x = [0.05, 0.1, 0.2, 0.5, 1, 5]
# x = range(1, len(r_1) + 1)

plt.figure(figsize=(6, 5))
#plt.plot(loss1, linestyle = '--', label='Non-private')
plt.axhline(bs_1,linestyle = '--')
plt.plot(x, bs_2)
plt.plot(x, bs_3)
plt.plot(x, bs_4)
plt.legend(['Non-private','Gaussian','Laplacian','TrLaplacian'], loc = 'lower right')
plt.xlabel('$\epsilon$')
plt.ylabel('BERT-Score')
plt.savefig("BERT-Score_yelp_2.png", dpi=500,format="png")

# %%
x = [0.05, 0.1, 0.2, 0.5, 1]
Nw_1 = 0.706
Nw_2 = [0.144, 0.381, 0.608, 0.694, 0.708] # 0.725, 0.708, 0.739
Nw_3 = [0.052, 0.138, 0.525, 0.646, 0.691] # 0.721, 0.704, 0.699
Nw_4 = [0.705, 0.721, 0.722, 0.725, 0.724] # 0.700, 0.712, 0.740

plt.figure(figsize=(6, 5))
plt.axhline(Nw_1,linestyle = '--')
plt.plot(x, Nw_2)
plt.plot(x, Nw_3)
plt.plot(x, Nw_4)
plt.fill_between(x, Nw_2, 0.144, facecolor = 'Pink', alpha = 0.3)
plt.fill_between(x, Nw_3, 0.052, facecolor = 'Cyan', alpha = 0.1)
plt.fill_between(x, Nw_4, 0.052, facecolor = 'Purple', alpha = 0.05)
plt.legend(['Non-private','Gaussian','Laplacian','TrLaplacian'], loc = 'lower right')
plt.xlabel('Privacy budget $\epsilon$')
plt.ylabel('$N_w$ Value')
plt.savefig("Nw_yelp_4.png", dpi=500,format="png")

# %%
loss_1 = 2.95
r_1 = 92.37
bs_1 = 0.975

loss_2 = [51.25, 26.66, 9.92, 5.97, 4.28] # 3.01, 3.03, 2.98 
r_2 = [14.01, 59.52, 83.61, 89.06, 90.97] # 92.27, 92.16, 92.19 
bs_2 = [0.849, 0.908, 0.955, 0.963, 0.968] # 0.973, 0.971, 0.972

loss_3 = [51.43, 37.86, 15.35, 7.31, 4.93] # 3.24, 3.05, 3.13
r_3 = [13.02, 43.30, 75.77, 86.98, 90.02] # 92.09, 92.28, 92.26
bs_3 = [0.839, 0.889, 0.942, 0.959, 0.966] # 0.970, 0.971, 0.971

loss_4 = [2.89, 2.86, 2.84, 3.04, 2.85] # 2.97, 2.92, 2.81
r_4 = [92.44, 92.43, 92.41, 92.25, 92.41] # 92.35 92.24, 92.45 
bs_4 =[0.976, 0.971, 0.971, 0.971, 0.974] # 0.972, 0.975, 0.974


x = [0.05, 0.1, 0.2, 0.5, 1]
# x = range(1, len(r_1) + 1)

plt.figure(figsize=(6, 5))
#plt.plot(loss1, linestyle = '--', label='Non-private')
plt.axhline(loss_1,linestyle = '--')
plt.plot(x, loss_2)
plt.plot(x, loss_3)
plt.plot(x, loss_4)
plt.legend(['Non-private','Gaussian','Laplacian','TrLaplacian'], loc = 'upper right')
plt.xlabel('$\epsilon$')
plt.ylabel('loss')
plt.savefig("loss_yahoo_2.png", dpi=500,format="png")

# %%
x = [0.05, 0.1, 0.2, 0.5, 1, 5]
Nw_1 = 0.703
Nw_2 = [0.072, 0.511, 0.595, 0.628, 0.637, 0.680] # 0.664, 0.672
Nw_3 = [0.066, 0.334, 0.566, 0.642, 0.660, 0.658] # 0.675, 0.655
Nw_4 = [0.706, 0.682, 0.666, 0.662, 0.674, 0.670] # 0.702, 0.680

plt.figure(figsize=(6, 5))
plt.axhline(Nw_1,linestyle = '--')
plt.plot(x, Nw_2)
plt.plot(x, Nw_3)
plt.plot(x, Nw_4)
plt.fill_between(x, Nw_2, 0.072, facecolor = 'Pink', alpha = 0.3)
plt.fill_between(x, Nw_3, 0.066, facecolor = 'Cyan', alpha = 0.1)
plt.fill_between(x, Nw_4, 0.066, facecolor = 'Purple', alpha = 0.05)
plt.legend(['Non-private','Gaussian','Laplacian','TrLaplacian'], loc = 'lower right')
plt.xlabel('Privacy budget $\epsilon$')
plt.ylabel('$N_w$ Value')
plt.savefig("Nw_yahoo_4.png", dpi=500,format="png")
